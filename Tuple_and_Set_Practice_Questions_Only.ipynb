# %% [markdown]
# # Python Practice: Tuple and Set (Practice Only)
#
# This notebook contains **practice questions only** on **Tuples** and **Sets**.
#
# Instructions:
# - Questions are written in **text cells**
# - Write your solution in the **code cell below each question**
# - Do NOT use any advanced concepts

# %% [markdown]
# ##  Tuple Practice Questions

# %% [markdown]
# ### Question 1
# Create a tuple of 5 integers and print it.

# %%
# write your answer here
myTuple = 2,5,4,8,3
print(myTuple)
# Out:
# (2, 5, 4, 8, 3)

# %% [markdown]
# ### Question 2
# Create a tuple with different data types (int, float, string, boolean) and print each element separately.

# %%
# write your answer here
tuple1 = (25, 13.4, "abc", True)
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
print(tuple1[3])
# Out:
# 25
# 13.4
# abc
# True

# %% [markdown]
# ### Question 3
# Find the length of a tuple containing names of 4 students.

# %%
# write your answer here
tuple1 = ("Aman","Bablu","Charle","Dev")
print(len(tuple1))
# Out:
# 4

# %% [markdown]
# ### Question 4
# Access and print the last element of a tuple.

# %%
# write your answer here
tuple1 = ("Aman","Bablu","Charle","Dev")
print(tuple1[-1])
# Out:
# Dev

# %% [markdown]
# ### Question 5
# Check whether an element exists in a tuple or not.

# %%
# write your answer here
tuple1 = ("Aman","Bablu","Charle","Dev")

if "Dev" in tuple1 :
  print("Exists")
else :
  print("Not Exists")
# Out:
# Exists

# %% [markdown]
# ### Question 6
# Convert a tuple into a list.

# %%
# write your answer here
tuple1 = (25, 13.4, "abc", True)
mylist = list(tuple1)
print(mylist,type(mylist))
# Out:
# [25, 13.4, 'abc', True] <class 'list'>

# %% [markdown]
# ### Question 7
# Convert a list into a tuple.

# %%
# write your answer here
mylist = [25, 13.4, "abc", True]
mytuple = tuple(mylist)
print(mytuple,type(mytuple))
# Out:
# (25, 13.4, 'abc', True) <class 'tuple'>

# %% [markdown]
# ### Question 8
# Create a tuple with repeated values and count how many times an element appears.

# %%
# write your answer here
tuple1 = ("abc", 34, True, 40, "male", 40)
print(tuple1.count(40))
# Out:
# 2

# %% [markdown]
# ### Question 9
# Find the index of an element in a tuple.

# %%
# write your answer here
tuple1 = ("abc", 34, True, 40, "male")
print(tuple1.index(40))
# Out:
# 3

# %% [markdown]
# ### Question 10
# Demonstrate that tuples are immutable (cannot be changed).

# %%
# write your answer here
tuple1 = ("abc", 34, True, 40, "male")
tuple[0] = "def"
print(tuple1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2186667664.py in <cell line: 0>()
#       1 # write your answer here
#       2 tuple1 = ("abc", 34, True, 40, "male")
# ----> 3 tuple[0] = "def"
#       4 print(tuple1)
#
# TypeError: 'type' object does not support item assignment
